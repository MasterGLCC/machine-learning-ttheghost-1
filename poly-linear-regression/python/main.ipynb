# %%
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
import matplotlib.pyplot as plt
import numpy as np

# %%
# Génération de données aléatoires avec une relation quadratique (y = x^2)
np.random.seed(0)
X = 2 - 3 * np.random.normal(0, 1, (100, 1))
y = X - 2 * (X ** 2) + 0.5 * (X ** 3) # Un peu complexe pour la démo
# Simplifions pour du degré 2 :
y = 1 + 2*X + 5*(X**2) + np.random.normal(-5, 5, (100, 1))

# Generer des données pour une regression polynomiale de degré 2 simple
# X, y = make_regression(n_samples=100, n_features=1, noise=20, random_state=42)

# %%
# Créer le modèle de regression polynomiale de degré 2
degree = 2
model = make_pipeline(PolynomialFeatures(degree=degree), LinearRegression())

# Entraînement du modèle
model.fit(X, y)

# Faire des prédictions
y_pred = model.predict(X)

# %%
X_plot = np.linspace(X.min(), X.max(), 100).reshape(-1, 1)
y_plot = model.predict(X_plot)

# afficher les données et la ligne de regression
plt.scatter(X, y, color='blue', label='Données réelles')
plt.plot(X_plot, y_plot, color='red', label='Ligne de regression')
plt.xlabel('Feature')
plt.ylabel('Target')
plt.title('Regression polynomiale de degré 2')
plt.legend()
plt.show()
